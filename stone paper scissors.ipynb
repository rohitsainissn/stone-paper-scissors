# %%
from PIL import Image
 
# creating a object
im = Image.open('stone.jpeg')

im.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 from PIL import Image
#       3 # creating a object
# ----> 4 im = Image.open('stone.jpeg')
#       7 im.show()
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/PIL/Image.py:3227, in open(fp, mode, formats)
#    3224     filename = fp
#    3226 if filename:
# -> 3227     fp = builtins.open(filename, "rb")
#    3228     exclusive_fp = True
#    3230 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'stone.jpeg'

# %%
import pyttsx3

engine = pyttsx3.init()

voices = engine.getProperty('voices')

engine.setProperty('voice', voices[0].id)

rate = engine.getProperty('rate')

engine.setProperty('rate', 150)
print('enter \n s for Stone \n c for Scissor\n p for Paper\n')
import random
lis = ["Stone","Scissors","Paper"]
def comp_chance(lis):
    pc=random.choice(lis)
    return pc
r=c=0
name = 'Devansh'
# input("enter your name \n")

def rohit_chance(rohit):
    if rohit == "s":
        return "Stone"
    elif rohit == "c":
        return "Scissors"
    elif rohit == "p":
        return "Paper"
    else:
        print ("wrong entry")
        engine.say("wrong entry")
        engine.runAndWait()


def w():
    global r
    r=r+1
    engine.say("congratulation ")

    return "congratulation"
def l():
    global c
    c=c+1
    engine.say('looser')

    return'looser'


wi =0
lo = 0
while r<5 and c <5 and wi<5 and lo<5:
    var = comp_chance(lis)
    rohit = input("")
    engine.say(var)

    bari = print(f'{name} {rohit_chance(rohit)} V/S Computer {var}')

    if rohit_chance(rohit) == var:
        print ("this point is draw")
        engine.say('Tie')       

    if rohit_chance(rohit) == "Stone":
        if var=="Scissors":
            print (name,w())
            wi+=1
        elif var=="Paper":
            print (name,l())
            lo+=1


    elif rohit_chance(rohit) == "Scissors":
        if var=="Stone":
            print (name, l())
            lo+=1
        elif var=="Paper":
            print (name, w())
            wi+=1

    elif rohit_chance(rohit) == "Paper":
        if var=="Stone":
            print (name, w())
            wi+=1
        elif var=="Scissors":
            print (name, l())
            lo+=1
    print("Score", name, "V/S Computer", r, ":", c)
    sco1,sco2= str(r),str(c)
    engine.say(sco1)
    engine.say(sco2)
    engine.runAndWait()

print("End of the game")
engine.say("End of the game")

if r>c:
    print(name," won the game")
    engine.say("you win hurraaaa")
    engine.runAndWait()
    
elif c>r:
    print("Computer win, better luck next time")
    engine.say("Computer win, better luck next time")
    engine.runAndWait()
    print("Computer win, better luck next time")
elif c==r:
    print("Match Draw")
    engine.say("Match Draw")
    engine.runAndWait()
    
final =f'final score", {name}, "V/S Computer",{r},":",{c}'
print(final) 
engine.say(final)
engine.runAndWait()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 from PIL import Image
#       3 # creating a object
# ----> 4 im = Image.open(r"C:\Users\System-Pc\Desktop\home.png")
#       6 im.show()
#       7 import pyttsx3
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/PIL/Image.py:3227, in open(fp, mode, formats)
#    3224     filename = fp
#    3226 if filename:
# -> 3227     fp = builtins.open(filename, "rb")
#    3228     exclusive_fp = True
#    3230 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\System-Pc\\Desktop\\home.png'
